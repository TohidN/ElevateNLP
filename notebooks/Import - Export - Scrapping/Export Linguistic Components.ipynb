# %%
# Imports
import os, json
from django.conf import settings
from mptt.templatetags.mptt_tags import cache_tree_children

# %%
# Recursive tree to handle nested components
def get_component_children(component, level):
    if level == 0:
        children = Component.objects.all()
        children = cache_tree_children(children)
    else:
        children = Component.get_children(component)
    index = 0
    child_data = {}
    for child in children:
        child_data[index] = {}
        child_data[index]["title"] = child.title
        child_data[index]["description"] = child.description
        child_data[index]["code"] = child.code
        child_data[index]["codes"] = child.codes
        child_data[index]["component_type"] = child.component_type
        child_data[index]["references"] = {}
        r_count = 0
        for reference in child.references.all():
            child_data[index]["references"][r_count] = {
                "title": reference.title,
                "description": reference.description,
                "url": reference.url,
            }

        child_data[index]["data"] = child.data
        child_data[index]["children"] = get_component_children(child, level=level + 1)
        index = index + 1
    return child_data

# %%
# Convert linguistic components data to json
data = get_component_children(component=None, level=0)
print(json.dumps(data, indent=4))
# Out:
# {
#     "0": {
#         "title": "Features",
#         "description": "Universal Morphological Features (UFeats)",
#         "code": "FEATURE",
#         "codes": {},
#         "component_type": [],
#         "references": {},
#         "data": {},
#         "children": {
#             "0": {
#                 "title": "a foreign word",
#                 "description": "Is this a foreign word? Not a loan word and not a foreign name but a genuinely foreign word appearing inside native text, e.g. inside direct speech, titles of books etc.",
#                 "code": "FOREIGN",
#                 "codes": {
#                     "ud": "Foreign"
#                 },
#                 "component_type": [
#                     "Morphosyntactic Relationship"
#                 ],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/feat/Foreign.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "1": {
#                 "title": "abbreviation",
#                 "description": "Is this an abbreviation? Note that the abbreviated word(s) typically belongs to a part of speech other than X.",
#                 "code": "ABBR",
#                 "codes": {
#                     "ud": "Abbr"
#                 },
#                 "component_type": [
#                     "Morphosyntactic Relationship"
#                 ],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/feat/Abbr.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "2": {
#                 "title": "animacy",
#                 "description": "Similarly to Gender (and to the African noun classes), animacy is usually a lexical feature of nouns and inflectional feature of other parts of speech (pronouns, adjectives, determiners, numerals, verbs) that mark agreement with nouns.",
#                 "code": "ANIMACY",
#                 "codes": {
#                     "ud": "Animacy"
#                 },
#                 "component_type": [
#                     "Morphosyntactic Relationship"
#                 ],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/feat/Animacy.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {
#                     "0": {
#                         "title": "Animate",
#                         "description": null,
#                         "code": "ANIM",
#                         "codes": {
#                             "ud": "Anim"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "https://universaldependencies.org/u/feat/Animacy.html#Anim"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "1": {
#                         "title": "Human",
#                         "description": null,
#                         "code": "HUM",
#                         "codes": {
#                             "ud": "Hum"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "https://universaldependencies.org/u/feat/Animacy.html#Hum"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "2": {
#                         "title": "Inan",
#                         "description": null,
#                         "code": "INAN",
#                         "codes": {
#                             "ud": "Inan"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "https://universaldependencies.org/u/feat/Animacy.html#Inan"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "3": {
#                         "title": "Non-human",
#                         "description": null,
#                         "code": "NHUM",
#                         "codes": {
#                             "ud": "Nhum"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "https://universaldependencies.org/u/feat/Animacy.html#Nhum"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     }
#                 }
#             },
#             "3": {
#                 "title": "Aspect",
#                 "description": "Aspect is a feature that specifies duration of the action in time, whether the action has been completed etc.",
#                 "code": "ASPECT",
#                 "codes": {
#                     "ud": "Aspect"
#                 },
#                 "component_type": [
#                     "Morphosemantic Property"
#                 ],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/feat/Aspect.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {
#                     "0": {
#                         "title": "Completive Aspect",
#                         "description": null,
#                         "code": "COMPLETIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/CompletiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "1": {
#                         "title": "Continuous Aspect",
#                         "description": null,
#                         "code": "CONTINUOUSASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ContinuousAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "2": {
#                         "title": "Distributive Aspect",
#                         "description": null,
#                         "code": "DISTRIBUTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/DistributiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "3": {
#                         "title": "Durative Aspect",
#                         "description": null,
#                         "code": "DURATIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/DurativeAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "4": {
#                         "title": "Frequentive Aspect",
#                         "description": null,
#                         "code": "FREQUENTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/FrequentiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "5": {
#                         "title": "Hab",
#                         "description": null,
#                         "code": "HAB",
#                         "codes": {
#                             "ud": "Hab"
#                         },
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {},
#                         "data": {},
#                         "children": {}
#                     },
#                     "6": {
#                         "title": "Habitual Aspect",
#                         "description": null,
#                         "code": "HABITUALASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/HabitualAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "7": {
#                         "title": "Imperfective Aspect",
#                         "description": null,
#                         "code": "IMPERFECTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ImperfectiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "8": {
#                         "title": "Inceptive Aspect",
#                         "description": null,
#                         "code": "INCEPTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InceptiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "9": {
#                         "title": "Iter",
#                         "description": null,
#                         "code": "ITER",
#                         "codes": {
#                             "ud": "Iter"
#                         },
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {},
#                         "data": {},
#                         "children": {}
#                     },
#                     "10": {
#                         "title": "Iterative Aspect",
#                         "description": null,
#                         "code": "ITERATIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/IterativeAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "11": {
#                         "title": "Non Progressive Aspect",
#                         "description": null,
#                         "code": "NONPROGRESSIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/NonProgressiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "12": {
#                         "title": "Perf",
#                         "description": null,
#                         "code": "PERF",
#                         "codes": {
#                             "ud": "Perf"
#                         },
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {},
#                         "data": {},
#                         "children": {}
#                     },
#                     "13": {
#                         "title": "Perfective Aspect",
#                         "description": null,
#                         "code": "PERFECTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/PerfectiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "14": {
#                         "title": "Phasal Aspect",
#                         "description": null,
#                         "code": "PHASALASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/PhasalAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "15": {
#                         "title": "Prog",
#                         "description": null,
#                         "code": "PROG",
#                         "codes": {
#                             "ud": "Prog"
#                         },
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {},
#                         "data": {},
#                         "children": {}
#                     },
#                     "16": {
#                         "title": "Progressive Aspect",
#                         "description": null,
#                         "code": "PROGRESSIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ProgressiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "17": {
#                         "title": "Prosp",
#                         "description": null,
#                         "code": "PROSP",
#                         "codes": {
#                             "ud": "Prosp"
#                         },
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {},
#                         "data": {},
#                         "children": {}
#                     },
#                     "18": {
#                         "title": "Quantificational Aspect",
#                         "description": null,
#                         "code": "QUANTIFICATIONALASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/QuantificationalAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "19": {
#                         "title": "Semelfactive Aspect",
#                         "description": null,
#                         "code": "SEMELFACTIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/SemelfactiveAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "20": {
#                         "title": "Simultaneous Aspect",
#                         "description": null,
#                         "code": "SIMULTANEOUSASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/SimultaneousAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "21": {
#                         "title": "Terminative Aspect",
#                         "description": null,
#                         "code": "TERMINATIVEASPECT",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosemantic Property"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/TerminativeAspect"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     }
#                 }
#             },
#             "4": {
#                 "title": "Case",
#                 "description": null,
#                 "code": null,
#                 "codes": {},
#                 "component_type": [
#                     "Morphosyntactic Relationship"
#                 ],
#                 "references": {},
#                 "data": {},
#                 "children": {
#                     "0": {
#                         "title": "Abessive Case",
#                         "description": null,
#                         "code": "CASE:ABESSIVE",
#                         "codes": {
#                             "ud": "Abe"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AbessiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "1": {
#                         "title": "Ablative Case",
#                         "description": null,
#                         "code": "CASE:ABLATIVE",
#                         "codes": {
#                             "ud": "Abl"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AblativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "2": {
#                         "title": "Absolutive Case",
#                         "description": null,
#                         "code": "CASE:ABSOLUTIVE",
#                         "codes": {
#                             "ud": "Abs"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AbsolutiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "3": {
#                         "title": "Accusative Case",
#                         "description": null,
#                         "code": "CASE:ACCUSATIVE",
#                         "codes": {
#                             "ud": "Acc"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AccusativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "4": {
#                         "title": "Adessive Case",
#                         "description": null,
#                         "code": "CASE:ADESSIVE",
#                         "codes": {
#                             "ud": "Ade"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AdessiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "5": {
#                         "title": "Allative Case",
#                         "description": null,
#                         "code": "CASE:ALLATIVE",
#                         "codes": {
#                             "ud": "All"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AllativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "6": {
#                         "title": "Aversive Case",
#                         "description": null,
#                         "code": "AVERSIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/AversiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "7": {
#                         "title": "Benefactive Case",
#                         "description": null,
#                         "code": "CASE:BENEFACTIVE",
#                         "codes": {
#                             "ud": "Ben"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/BenefactiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "8": {
#                         "title": "Comitative Case",
#                         "description": null,
#                         "code": "CASE:COMITATIVE",
#                         "codes": {
#                             "ud": "Com"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ComitativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "9": {
#                         "title": "Contablative Case",
#                         "description": null,
#                         "code": "CONTABLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ContablativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "10": {
#                         "title": "Contallative Case",
#                         "description": null,
#                         "code": "CONTALLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ContallativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "11": {
#                         "title": "Conterminative Case",
#                         "description": null,
#                         "code": "CONTERMINATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ConterminativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "12": {
#                         "title": "Contlative Case",
#                         "description": null,
#                         "code": "CONTLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ContlativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "13": {
#                         "title": "Dative Case",
#                         "description": null,
#                         "code": "CASE:DATIVE",
#                         "codes": {
#                             "ud": "Dat"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/DativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "14": {
#                         "title": "Delative Case",
#                         "description": null,
#                         "code": "CASE:DELATIVE",
#                         "codes": {
#                             "ud": "Del"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/DelativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "15": {
#                         "title": "Elative Case",
#                         "description": null,
#                         "code": "CASE:ELATIVE",
#                         "codes": {
#                             "ud": "Ela"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ElativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "16": {
#                         "title": "Ergative Case",
#                         "description": null,
#                         "code": "CASE:ERGATIVE",
#                         "codes": {
#                             "ud": "Erg"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/ErgativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "17": {
#                         "title": "Essive Case",
#                         "description": null,
#                         "code": "CASE:ESSIVE",
#                         "codes": {
#                             "ud": "Ess"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/EssiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "18": {
#                         "title": "Genitive Case",
#                         "description": null,
#                         "code": "CASE:GENITIVE",
#                         "codes": {
#                             "ud": "Gen"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/GenitiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "19": {
#                         "title": "Illative Case",
#                         "description": null,
#                         "code": "CASE:ILLATIVE",
#                         "codes": {
#                             "ud": "Ill"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/IllativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "20": {
#                         "title": "Inablative Case",
#                         "description": null,
#                         "code": "INABLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InablativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "21": {
#                         "title": "Inallative Case",
#                         "description": null,
#                         "code": "INALLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InallativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "22": {
#                         "title": "Inessive Case",
#                         "description": null,
#                         "code": "CASE:INESSIVE",
#                         "codes": {
#                             "ud": "Ine"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InessiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "23": {
#                         "title": "Instrumental Case",
#                         "description": null,
#                         "code": "CASE:INSTRUMENTAL",
#                         "codes": {
#                             "ud": "Ins"
#                         },
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InstrumentalCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "24": {
#                         "title": "Interablative Case",
#                         "description": null,
#                         "code": "INTERABLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InterablativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "25": {
#                         "title": "Interallative Case",
#                         "description": null,
#                         "code": "INTERALLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InterallativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "26": {
#                         "title": "Interessive Case",
#                         "description": null,
#                         "code": "INTERESSIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InteressiveCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "27": {
#                         "title": "Interlative Case",
#                         "description": null,
#                         "code": "INTERLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InterlativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "28": {
#                         "title": "Interminative Case",
#                         "description": null,
#                         "code": "INTERMINATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InterminativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "29": {
#                         "title": "Interterminative Case",
#                         "description": null,
#                         "code": "INTERTERMINATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/InterterminativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "30": {
#                         "title": "Intertranslative Case",
#                         "description": null,
#                         "code": "INTERTRANSLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
#                                 "title": "link",
#                                 "description": null,
#                                 "url": "http://purl.org/linguistics/gold/IntertranslativeCase"
#                             }
#                         },
#                         "data": {},
#                         "children": {}
#                     },
#                     "31": {
#                         "title": "Intranslative Case",
#                         "description": null,
#                         "code": "INTRANSLATIVECASE",
#                         "codes": {},
#                         "component_type": [
#                             "Morphosyntactic Relationship"
#                         ],
#                         "references": {
#                             "0": {
# ...
#                 "codes": {
#                     "ud": "orphan"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/orphan.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "42": {
#                 "title": "overridden disfluency",
#                 "description": "",
#                 "code": "REPARANDUM",
#                 "codes": {
#                     "ud": "reparandum"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/reparandum.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "43": {
#                 "title": "parataxis",
#                 "description": "",
#                 "code": "PARATAXIS",
#                 "codes": {
#                     "ud": "parataxis"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/parataxis.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "44": {
#                 "title": "passive auxiliary",
#                 "description": "",
#                 "code": "AUX:PASS",
#                 "codes": {
#                     "ud": "aux:pass"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/aux-pass.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "45": {
#                 "title": "passive nominal subject",
#                 "description": "",
#                 "code": "NSUBJ:PASS",
#                 "codes": {
#                     "ud": "nsubj:pass"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/nsubj-pass.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "46": {
#                 "title": "phrasal verb particle",
#                 "description": "",
#                 "code": "COMPOUND:PRT",
#                 "codes": {
#                     "ud": "compound:prt"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/compound-prt.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "47": {
#                 "title": "possessive determiner",
#                 "description": "",
#                 "code": "DET:POSS",
#                 "codes": {
#                     "ud": "det:poss"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/det-poss.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "48": {
#                 "title": "possessive nominal modifier",
#                 "description": "",
#                 "code": "NMOD:POSS",
#                 "codes": {
#                     "ud": "nmod:poss"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/nmod-poss.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "49": {
#                 "title": "preconjunct",
#                 "description": "",
#                 "code": "CC:PRECONJ",
#                 "codes": {
#                     "ud": "cc:preconj"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/cc-preconj.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "50": {
#                 "title": "pronominal quantifier agreeing in case with the noun",
#                 "description": "",
#                 "code": "DET:NUMMOD",
#                 "codes": {
#                     "ud": "det:nummod"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/det-nummod.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "51": {
#                 "title": "pronominal quantifier governing the case of the noun",
#                 "description": "",
#                 "code": "DET:NUMGOV",
#                 "codes": {
#                     "ud": "det:numgov"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/det-numgov.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "52": {
#                 "title": "punctuation",
#                 "description": "",
#                 "code": "UD_PUNCT",
#                 "codes": {
#                     "ud": "punct"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/punct.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "53": {
#                 "title": "reduplicated compounds",
#                 "description": "",
#                 "code": "COMPOUND:REDUP",
#                 "codes": {
#                     "ud": "compound:redup"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/compound-redup.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "54": {
#                 "title": "reflexive clitic with an inherently reflexive verb",
#                 "description": "",
#                 "code": "EXPL:PV",
#                 "codes": {
#                     "ud": "expl:pv"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/expl-pv.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "55": {
#                 "title": "reflexive pronoun used in reflexive passive",
#                 "description": "",
#                 "code": "EXPL:PASS",
#                 "codes": {
#                     "ud": "expl:pass"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/expl-pass.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "56": {
#                 "title": "relative clause modifier",
#                 "description": "",
#                 "code": "ACL:RELCL",
#                 "codes": {
#                     "ud": "acl:relcl"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/acl-relcl.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "57": {
#                 "title": "root",
#                 "description": "",
#                 "code": "ROOT",
#                 "codes": {
#                     "ud": "root"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/root.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "58": {
#                 "title": "serial verb compounds",
#                 "description": "",
#                 "code": "COMPOUND:SVC",
#                 "codes": {
#                     "ud": "compound:svc"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/compound-svc.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "59": {
#                 "title": "temporal modifier",
#                 "description": "",
#                 "code": "OBL:TMOD",
#                 "codes": {
#                     "ud": "obl:tmod"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/obl-tmod.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "60": {
#                 "title": "temporal modifier",
#                 "description": "",
#                 "code": "NMOD:TMOD",
#                 "codes": {
#                     "ud": "nmod:tmod"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/nmod-tmod.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "61": {
#                 "title": "unspecified dependency",
#                 "description": "",
#                 "code": "DEP",
#                 "codes": {
#                     "ud": "dep"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/dep.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             },
#             "62": {
#                 "title": "vocative",
#                 "description": "",
#                 "code": "VOCATIVE",
#                 "codes": {
#                     "ud": "vocative"
#                 },
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "https://universaldependencies.org/u/dep/vocative.html"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             }
#         }
#     },
#     "8": {
#         "title": "Word Collections",
#         "description": "Word collections for n-grams, semantic word collections, etc.",
#         "code": "WORD_COLLECTION",
#         "codes": {},
#         "component_type": [],
#         "references": {},
#         "data": {},
#         "children": {
#             "0": {
#                 "title": "N-Gram",
#                 "description": "A sequence of N words.\r\nN-grams might have meaning when coming together, E.g. San Francisco. Or they might represent an instance, E.g. \"To Kill a Mockingbird\". or they might not necessarily have a semantic or grammatical significance.\r\nfrequency of n-grams and other their other statistical properties provides insight into their relationship and is used in applications such as word prediction, or generative models in NLP.",
#                 "code": "NGRAM",
#                 "codes": {},
#                 "component_type": [],
#                 "references": {},
#                 "data": {},
#                 "children": {}
#             },
#             "1": {
#                 "title": "Part Of Speech N-grams",
#                 "description": "part of speech (POS) n-grams are contiguous sequences of parts of speech in a given phrase,",
#                 "code": "POS_NGRAM",
#                 "codes": {},
#                 "component_type": [],
#                 "references": {},
#                 "data": {},
#                 "children": {}
#             },
#             "2": {
#                 "title": "Semantic n-gram",
#                 "description": "Words that represent a single concept when used together. E.g. heavy-handed, ill-advised, fast asleep, set in stone.\r\nIn English they can be separated by '-' or space.",
#                 "code": "SEMANTIC_NGRAM",
#                 "codes": {},
#                 "component_type": [],
#                 "references": {},
#                 "data": {},
#                 "children": {}
#             },
#             "3": {
#                 "title": "Syntactic n-grams",
#                 "description": "Syntactic n-grams are n-grams defined by paths in syntactic dependency or constituent trees rather than the linear structure of the text.",
#                 "code": "SYNTATIC_NGRAM",
#                 "codes": {},
#                 "component_type": [],
#                 "references": {
#                     "0": {
#                         "title": "link",
#                         "description": null,
#                         "url": "http://www.cic.ipn.mx/~sidorov/sn_grams_MICAI2012.pdf"
#                     }
#                 },
#                 "data": {},
#                 "children": {}
#             }
#         }
#     }
# }

# %%
# Write to Json file
path = os.path.join(
    settings.BASE_DIR, "../dataset/linguistics/dump_json_components_new.json"
)
with open(path, "w") as outfile:
    json.dump(data, outfile)

# %%
# OPTIONAL: it helps prevent problems regarding item orders and tree representation in admin menu
Component.objects.rebuild()
